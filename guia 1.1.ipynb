# %% [markdown]
# <a href="https://colab.research.google.com/github/fglimberg/Taller-procesamiento/blob/main/guia%201.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
imagen = plt.imread('/content/pikachu_vs_charmander.jpeg')

# %%
imagen=imagen.astype(np.float32)

# %%
gris_a = (np.min(imagen, axis=2) + np.max(imagen, axis=2)) / 2

# %%
gris_a.dtype
# Out:
# dtype('float32')

# %%
plt.imshow(gris_a,cmap='gray')

# %%
gris_b = np.mean(imagen, axis=2)

# %%
plt.imshow(gris_b,cmap='gray')

# %%
gris_c_chat = 0.3*imagen[:,:,2] + 0.59*imagen[:,:,1] + 0.11*imagen[:,:,0]
pesos = [0.11,0.59,0.3]
gris_c_ramoide = imagen @ pesos

# %%
plt.imshow(gris_c_chat,cmap='gray')

# %%
plt.imshow(gris_c_ramoide)
